# %%
pip install mcp
# Out:
# Collecting mcp
#   Downloading mcp-2.0.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: anyio>=4.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp) (4.13.0)
# Collecting httpx2>=2.5.0 (from mcp)
#   Downloading httpx2-2.10.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jsonschema>=4.20.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp) (4.26.0)
# Collecting mcp-types==2.0.0 (from mcp)
#   Downloading mcp_types-2.0.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-api>=1.28.0 (from mcp)
#   Downloading opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pydantic>=2.12.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp) (2.13.4)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->mcp)
#   Downloading pyjwt-2.13.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: python-multipart>=0.0.9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp) (0.0.32)
# Collecting sse-starlette>=3.0.0 (from mcp)
#   Downloading sse_starlette-3.4.8-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: starlette>=0.48.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.13.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from mcp) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp) (0.48.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anyio>=4.10->mcp) (3.16)
# Collecting httpcore2==2.10.0 (from httpx2>=2.5.0->mcp)
#   Downloading httpcore2-2.10.0-py3-none-any.whl.metadata (25 kB)
# Collecting idna>=2.8 (from anyio>=4.10->mcp)
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting truststore>=0.10 (from httpx2>=2.5.0->mcp)
#   Downloading truststore-0.10.4-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpcore2==2.10.0->httpx2>=2.5.0->mcp) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp) (2026.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic>=2.12.0->mcp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic>=2.12.0->mcp) (2.46.4)
# Requirement already satisfied: cryptography>=3.4.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pyjwt[crypto]>=2.10.1->mcp) (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp) (3.0)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from uvicorn>=0.31.1->mcp) (8.4.2)
# Downloading mcp-2.0.0-py3-none-any.whl (349 kB)
# Downloading mcp_types-2.0.0-py3-none-any.whl (69 kB)
# Downloading httpx2-2.10.0-py3-none-any.whl (94 kB)
# Downloading httpcore2-2.10.0-py3-none-any.whl (83 kB)
# Using cached idna-3.18-py3-none-any.whl (65 kB)
# Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
# Downloading pyjwt-2.13.0-py3-none-any.whl (31 kB)
# Downloading sse_starlette-3.4.8-py3-none-any.whl (16 kB)
# Downloading truststore-0.10.4-py3-none-any.whl (18 kB)
# Installing collected packages: truststore, pyjwt, opentelemetry-api, idna, httpcore2, mcp-types, httpx2, sse-starlette, mcp
#   Attempting uninstall: idna
#     Found existing installation: idna 3.16
#     Uninstalling idna-3.16:
#       Successfully uninstalled idna-3.16
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [mcp]m━━━━━━━━━━━━━ 6/9 [httpx2]
# Successfully installed httpcore2-2.10.0 httpx2-2.10.0 idna-3.18 mcp-2.0.0 mcp-types-2.0.0 opentelemetry-api-1.44.0 pyjwt-2.13.0 sse-starlette-3.4.8 truststore-0.10.4
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.3.14-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchain) (1.5.3)
# Collecting langgraph<1.3.0,>=1.2.5 (from langchain)
#   Downloading langgraph-1.2.10-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.10.17)
# Requirement already satisfied: packaging>=23.2.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_checkpoint-4.2.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached ormsgpack-1.12.2-cp314-cp314-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Collecting websockets<16,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached websockets-15.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: anyio>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (4.13.0)
# Requirement already satisfied: distro>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.25.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.7.0)
# Downloading langchain-1.3.14-py3-none-any.whl (139 kB)
# Downloading langgraph-1.2.10-py3-none-any.whl (247 kB)
# Downloading langgraph_checkpoint-4.2.0-py3-none-any.whl (56 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Using cached langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Using cached websockets-15.0.1-py3-none-any.whl (169 kB)
# Using cached ormsgpack-1.12.2-cp314-cp314-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (378 kB)
# Installing collected packages: websockets, ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#   Attempting uninstall: websockets
#     Found existing installation: websockets 16.0
#     Uninstalling websockets-16.0:
#       Successfully uninstalled websockets-16.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [langchain]━━━━━━━━ 4/7 [langgraph-prebuilt]
# Successfully installed langchain-1.3.14 langgraph-1.2.10 langgraph-checkpoint-4.2.0 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2 ormsgpack-1.12.2 websockets-15.0.1
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.11.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.55.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (49.0.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.4)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (1.2.2)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install httpx
# Out:
# Requirement already satisfied: httpx in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (0.28.1)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx) (4.13.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx) (3.18)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpcore==1.*->httpx) (0.16.0)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U "mcp[cli]"
# Out:
# Requirement already satisfied: mcp[cli] in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.0.0)
# Requirement already satisfied: anyio>=4.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (4.13.0)
# Requirement already satisfied: httpx2>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (2.10.0)
# Requirement already satisfied: jsonschema>=4.20.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (4.26.0)
# Requirement already satisfied: mcp-types==2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (2.0.0)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (1.44.0)
# Requirement already satisfied: pydantic>=2.12.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (2.13.4)
# Requirement already satisfied: pyjwt>=2.10.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pyjwt[crypto]>=2.10.1->mcp[cli]) (2.13.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (0.0.32)
# Requirement already satisfied: sse-starlette>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (3.4.8)
# Requirement already satisfied: starlette>=0.48.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.13.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from mcp[cli]) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (0.48.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from mcp[cli]) (1.2.2)
# Requirement already satisfied: typer>=0.16.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (0.27.1)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anyio>=4.10->mcp[cli]) (3.18)
# Requirement already satisfied: httpcore2==2.10.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx2>=2.5.0->mcp[cli]) (2.10.0)
# Requirement already satisfied: truststore>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx2>=2.5.0->mcp[cli]) (0.10.4)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpcore2==2.10.0->httpx2>=2.5.0->mcp[cli]) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp[cli]) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp[cli]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp[cli]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp[cli]) (2026.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic>=2.12.0->mcp[cli]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic>=2.12.0->mcp[cli]) (2.46.4)
# Requirement already satisfied: cryptography>=3.4.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pyjwt[crypto]>=2.10.1->mcp[cli]) (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp[cli]) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp[cli]) (3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from typer>=0.16.0->mcp[cli]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from typer>=0.16.0->mcp[cli]) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from typer>=0.16.0->mcp[cli]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from rich>=13.8.0->typer>=0.16.0->mcp[cli]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from rich>=13.8.0->typer>=0.16.0->mcp[cli]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.16.0->mcp[cli]) (0.1.2)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from uvicorn>=0.31.1->mcp[cli]) (8.4.2)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U "mcp[cli]" google-genai python-dotenv httpx nest_asyncio
# Out:
# Requirement already satisfied: google-genai in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.11.0)
# Collecting google-genai
#   Using cached google_genai-2.17.0-py3-none-any.whl.metadata (56 kB)
# Requirement already satisfied: python-dotenv in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (1.2.2)
# Requirement already satisfied: httpx in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (0.28.1)
# Collecting nest_asyncio
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: mcp[cli] in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.0.0)
# Requirement already satisfied: anyio>=4.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (4.13.0)
# Requirement already satisfied: httpx2>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (2.10.0)
# Requirement already satisfied: jsonschema>=4.20.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (4.26.0)
# Requirement already satisfied: mcp-types==2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (2.0.0)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (1.44.0)
# Requirement already satisfied: pydantic>=2.12.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (2.13.4)
# Requirement already satisfied: pyjwt>=2.10.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pyjwt[crypto]>=2.10.1->mcp[cli]) (2.13.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (0.0.32)
# Requirement already satisfied: sse-starlette>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (3.4.8)
# Requirement already satisfied: starlette>=0.48.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.13.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from mcp[cli]) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (0.48.0)
# Requirement already satisfied: typer>=0.16.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from mcp[cli]) (0.27.1)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Using cached google_auth-2.56.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=41.0.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (49.0.0)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpcore==1.*->httpx) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic>=2.12.0->mcp[cli]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic>=2.12.0->mcp[cli]) (2.46.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cryptography>=41.0.5->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=41.0.5->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Requirement already satisfied: httpcore2==2.10.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx2>=2.5.0->mcp[cli]) (2.10.0)
# Requirement already satisfied: truststore>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx2>=2.5.0->mcp[cli]) (0.10.4)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp[cli]) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp[cli]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp[cli]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jsonschema>=4.20.0->mcp[cli]) (2026.5.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from typer>=0.16.0->mcp[cli]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from typer>=0.16.0->mcp[cli]) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from typer>=0.16.0->mcp[cli]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from rich>=13.8.0->typer>=0.16.0->mcp[cli]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from rich>=13.8.0->typer>=0.16.0->mcp[cli]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.16.0->mcp[cli]) (0.1.2)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from uvicorn>=0.31.1->mcp[cli]) (8.4.2)
# Using cached google_genai-2.17.0-py3-none-any.whl (1.0 MB)
# Using cached google_auth-2.56.3-py3-none-any.whl (259 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Installing collected packages: nest_asyncio, google-auth, google-genai
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.55.2
#     Uninstalling google-auth-2.55.2:
#       Successfully uninstalled google-auth-2.55.2
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.11.0
#     Uninstalling google-genai-2.11.0:
#       Successfully uninstalled google-genai-2.11.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [google-genai]━━━━━ 2/3 [google-genai]
# Successfully installed google-auth-2.56.3 google-genai-2.17.0 nest_asyncio-1.6.0
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import json

# %%
import requests

# %%
import sys

# %%
import httpx

# %%
import getpass

# %%
import os

# %%
import asyncio

# %%
import nest_asyncio

# %%
import os
import json
import httpx
import asyncio
import nest_asyncio

from getpass import getpass

nest_asyncio.apply()

print("Libraries loaded successfully.")
# Out:
# Libraries loaded successfully.

# %%
GEMINI_API_KEY = getpass("Enter your Google AI Studio API key: ")

os.environ["GEMINI_API_KEY"] = GEMINI_API_KEY

print("Gemini API key loaded.")
# Out:
# Enter your Google AI Studio API key:  ········
# Gemini API key loaded.

# %%
pip install google
# Out:
# Collecting google
#   Downloading google-3.0.0-py2.py3-none-any.whl.metadata (627 bytes)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from beautifulsoup4->google) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/aashishmewada/Library/Python/3.14/lib/python/site-packages (from beautifulsoup4->google) (4.16.0)
# Downloading google-3.0.0-py2.py3-none-any.whl (45 kB)
# Installing collected packages: google
# Successfully installed google-3.0.0
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai

# %%
from google import genai

gemini_client = genai.Client(
    api_key=os.environ["GEMINI_API_KEY"]
)
response = gemini_client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Explain MCP in one simple sentence. "
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[35], line 6
#       2
#       3 gemini_client = genai.Client(
#       4     api_key=os.environ["GEMINI_API_KEY"]
#       5 )
# ----> 6 response = gemini_client.models.generate_content(
#       7     model="gemini-2.5-flash",
#       8     contents="Explain MCP in one simple sentence. "
#       9 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/google/genai/models.py:6604, in Models.generate_content(self, model, contents, config)
#    6598   parsed_config_to_call = _extra_utils.get_usage_header(
#    6599       parsed_config_to_call,
#    6600       types.GenerateContentConfig,
#    6601       'afc',
#    6602   )
#    6603 i += 1
# -> 6604 response = self._generate_content(
#    6605     model=model, contents=contents, config=parsed_config_to_call
#    6606 )
#    6608 if not function_map:
#    6609   break
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/google/genai/models.py:5028, in Models._generate_content(self, model, contents, config)
#    5025 request_dict = _common.convert_to_dict(request_dict)
#    5026 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5028 response = self._api_client.request(
#    5029     'post', path, request_dict, http_options
#    5030 )
#    5032 if config is not None and getattr(
#    5033     config, 'should_return_http_response', None
#    5034 ):
#    5035   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/google/genai/_api_client.py:1708, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1698 def request(
#    1699     self,
#    1700     http_method: str,
#    (...)   1703     http_options: Optional[HttpOptionsOrDict] = None,
#    1704 ) -> SdkHttpResponse:
#    1705   http_request = self._build_request(
#    1706       http_method, path, request_dict, http_options
#    1707   )
# -> 1708   response = self._request(http_request, http_options, stream=False)
#    1709   response_body = (
#    1710       response.response_stream[0] if response.response_stream else ''
#    1711   )
#    1712   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/google/genai/_api_client.py:1495, in BaseApiClient._request(self, http_request, http_options, stream)
#    1492     retry = tenacity.Retrying(**retry_kwargs)
#    1493     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1495 return self._retry(self._request_once, http_request, stream)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/google/genai/_api_client.py:1472, in BaseApiClient._request_once(self, http_request, stream)
#    1464   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1465       method=http_request.method,
#    1466       url=http_request.url,
#    (...)   1469       timeout=http_request.timeout,
#    1470   )
#    1471   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1472 errors.APIError.raise_for_response(response)
#    1473 return HttpResponse(
#    1474     response.headers, response if stream else [response.text]
#    1475 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/google/genai/errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/google/genai/errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     170 """Raises an appropriate APIError subclass based on the status code.
#     171
#     172 Args:
#    (...)    181   APIError: For other error status codes.
#     182 """
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#     186   raise ServerError(status_code, response_json, response)
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.5-flash is no longer available to new users. Please update your code to use a newer model for the latest features and improvements. We recommend you to use the Interactions API (https://ai.google.dev/gemini-api/docs/migrate-to-interactions).', 'status': 'NOT_FOUND'}}
